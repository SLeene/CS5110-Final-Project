# %% [markdown]
# # CS 3110/5110: Data Privacy
# ## Homework 1

# %%
# Load the data and libraries
import pandas as pd
import numpy as np

adult = pd.read_csv('https://github.com/jnear/cs3110-data-privacy/raw/main/homework/adult_with_pii.csv')
adult_pii = adult[['Name', 'DOB', 'SSN', 'Zip', 'Age']]
adult_deid = adult.drop(columns=['Name', 'SSN'])

# %% [markdown]
# ## Question 1 (20 points)
#
# Using the dataframes `adult_pii` and `adult_deid`, write code to conduct a linking attack to recover the names of as many individuals in `adult_deid` as possible. Your solution should be parameterized by the set of columns to use in the attack.

# %%
adult
# Out:
#                     Name         DOB          SSN    Zip  Age  \
# 0       Karrie Trusslove    9/7/1967  732-14-6110  64152   39
# 1       Brandise Tripony    6/7/1988  150-19-2766  61523   50
# 2          Brenn McNeely    8/6/1991  725-59-9860  95668   38
# 3            Dorry Poter    4/6/2009  659-57-4974  25503   53
# 4            Dick Honnan   9/16/1951  220-93-3811  75387   28
# ...                  ...         ...          ...    ...  ...
# 32556       Ardyce Golby  10/29/1961  212-61-8338  41328   27
# 32557      Jean O'Connor   6/28/1952  737-32-2919  94735   40
# 32558   Reuben Skrzynski    8/9/1966  314-48-0219  49628   58
# 32559        Caye Biddle   5/19/1978  647-75-3550   8213   22
# 32560  Hortense Hardesty   5/11/2012  690-42-5638  86153   52
#
#               Workclass  fnlwgt   Education  Education-Num  \
# 0             State-gov   77516   Bachelors             13
# 1      Self-emp-not-inc   83311   Bachelors             13
# 2               Private  215646     HS-grad              9
# 3               Private  234721        11th              7
# 4               Private  338409   Bachelors             13
# ...                 ...     ...         ...            ...
# 32556           Private  257302  Assoc-acdm             12
# 32557           Private  154374     HS-grad              9
# 32558           Private  151910     HS-grad              9
# 32559           Private  201490     HS-grad              9
# 32560      Self-emp-inc  287927     HS-grad              9
#
#            Marital Status         Occupation   Relationship   Race     Sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# 1      Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2                Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3      Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4      Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ...                   ...                ...            ...    ...     ...
# 32556  Married-civ-spouse       Tech-support           Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 32558             Widowed       Adm-clerical      Unmarried  White  Female
# 32559       Never-married       Adm-clerical      Own-child  White    Male
# 32560  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        Capital Gain  Capital Loss  Hours per week        Country Target
# 0              2174             0              40  United-States  <=50K
# 1                 0             0              13  United-States  <=50K
# 2                 0             0              40  United-States  <=50K
# 3                 0             0              40  United-States  <=50K
# 4                 0             0              40           Cuba  <=50K
# ...             ...           ...             ...            ...    ...
# 32556             0             0              38  United-States  <=50K
# 32557             0             0              40  United-States   >50K
# 32558             0             0              40  United-States  <=50K
# 32559             0             0              20  United-States  <=50K
# 32560         15024             0              40  United-States   >50K
#
# [32561 rows x 19 columns]

# %%
adult_pii
# Out:
#                     Name         DOB          SSN    Zip  Age
# 0       Karrie Trusslove    9/7/1967  732-14-6110  64152   39
# 1       Brandise Tripony    6/7/1988  150-19-2766  61523   50
# 2          Brenn McNeely    8/6/1991  725-59-9860  95668   38
# 3            Dorry Poter    4/6/2009  659-57-4974  25503   53
# 4            Dick Honnan   9/16/1951  220-93-3811  75387   28
# ...                  ...         ...          ...    ...  ...
# 32556       Ardyce Golby  10/29/1961  212-61-8338  41328   27
# 32557      Jean O'Connor   6/28/1952  737-32-2919  94735   40
# 32558   Reuben Skrzynski    8/9/1966  314-48-0219  49628   58
# 32559        Caye Biddle   5/19/1978  647-75-3550   8213   22
# 32560  Hortense Hardesty   5/11/2012  690-42-5638  86153   52
#
# [32561 rows x 5 columns]

# %%
adult_deid
# Out:
#               DOB    Zip  Age         Workclass  fnlwgt   Education  \
# 0        9/7/1967  64152   39         State-gov   77516   Bachelors
# 1        6/7/1988  61523   50  Self-emp-not-inc   83311   Bachelors
# 2        8/6/1991  95668   38           Private  215646     HS-grad
# 3        4/6/2009  25503   53           Private  234721        11th
# 4       9/16/1951  75387   28           Private  338409   Bachelors
# ...           ...    ...  ...               ...     ...         ...
# 32556  10/29/1961  41328   27           Private  257302  Assoc-acdm
# 32557   6/28/1952  94735   40           Private  154374     HS-grad
# 32558    8/9/1966  49628   58           Private  151910     HS-grad
# 32559   5/19/1978   8213   22           Private  201490     HS-grad
# 32560   5/11/2012  86153   52      Self-emp-inc  287927     HS-grad
#
#        Education-Num      Marital Status         Occupation   Relationship  \
# 0                 13       Never-married       Adm-clerical  Not-in-family
# 1                 13  Married-civ-spouse    Exec-managerial        Husband
# 2                  9            Divorced  Handlers-cleaners  Not-in-family
# 3                  7  Married-civ-spouse  Handlers-cleaners        Husband
# 4                 13  Married-civ-spouse     Prof-specialty           Wife
# ...              ...                 ...                ...            ...
# 32556             12  Married-civ-spouse       Tech-support           Wife
# 32557              9  Married-civ-spouse  Machine-op-inspct        Husband
# 32558              9             Widowed       Adm-clerical      Unmarried
# 32559              9       Never-married       Adm-clerical      Own-child
# 32560              9  Married-civ-spouse    Exec-managerial           Wife
#
#         Race     Sex  Capital Gain  Capital Loss  Hours per week  \
# 0      White    Male          2174             0              40
# 1      White    Male             0             0              13
# 2      White    Male             0             0              40
# 3      Black    Male             0             0              40
# 4      Black  Female             0             0              40
# ...      ...     ...           ...           ...             ...
# 32556  White  Female             0             0              38
# 32557  White    Male             0             0              40
# 32558  White  Female             0             0              40
# 32559  White    Male             0             0              20
# 32560  White  Female         15024             0              40
#
#              Country Target
# 0      United-States  <=50K
# 1      United-States  <=50K
# 2      United-States  <=50K
# 3      United-States  <=50K
# 4               Cuba  <=50K
# ...              ...    ...
# 32556  United-States  <=50K
# 32557  United-States   >50K
# 32558  United-States  <=50K
# 32559  United-States  <=50K
# 32560  United-States   >50K
#
# [32561 rows x 17 columns]

# %%
def linking_attack(cols):
    # YOUR CODE HERE
    adult_merge = adult_pii.merge(adult_deid, on=cols)
    
    return adult_merge
adult_merged = linking_attack(['DOB','Zip','Age'])
adult_merged
# Out:
#                     Name         DOB          SSN    Zip  Age  \
# 0       Karrie Trusslove    9/7/1967  732-14-6110  64152   39
# 1       Brandise Tripony    6/7/1988  150-19-2766  61523   50
# 2          Brenn McNeely    8/6/1991  725-59-9860  95668   38
# 3            Dorry Poter    4/6/2009  659-57-4974  25503   53
# 4            Dick Honnan   9/16/1951  220-93-3811  75387   28
# ...                  ...         ...          ...    ...  ...
# 32556       Ardyce Golby  10/29/1961  212-61-8338  41328   27
# 32557      Jean O'Connor   6/28/1952  737-32-2919  94735   40
# 32558   Reuben Skrzynski    8/9/1966  314-48-0219  49628   58
# 32559        Caye Biddle   5/19/1978  647-75-3550   8213   22
# 32560  Hortense Hardesty   5/11/2012  690-42-5638  86153   52
#
#               Workclass  fnlwgt   Education  Education-Num  \
# 0             State-gov   77516   Bachelors             13
# 1      Self-emp-not-inc   83311   Bachelors             13
# 2               Private  215646     HS-grad              9
# 3               Private  234721        11th              7
# 4               Private  338409   Bachelors             13
# ...                 ...     ...         ...            ...
# 32556           Private  257302  Assoc-acdm             12
# 32557           Private  154374     HS-grad              9
# 32558           Private  151910     HS-grad              9
# 32559           Private  201490     HS-grad              9
# 32560      Self-emp-inc  287927     HS-grad              9
#
#            Marital Status         Occupation   Relationship   Race     Sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# 1      Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2                Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3      Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4      Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ...                   ...                ...            ...    ...     ...
# 32556  Married-civ-spouse       Tech-support           Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 32558             Widowed       Adm-clerical      Unmarried  White  Female
# 32559       Never-married       Adm-clerical      Own-child  White    Male
# 32560  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        Capital Gain  Capital Loss  Hours per week        Country Target
# 0              2174             0              40  United-States  <=50K
# 1                 0             0              13  United-States  <=50K
# 2                 0             0              40  United-States  <=50K
# 3                 0             0              40  United-States  <=50K
# 4                 0             0              40           Cuba  <=50K
# ...             ...           ...             ...            ...    ...
# 32556             0             0              38  United-States  <=50K
# 32557             0             0              40  United-States   >50K
# 32558             0             0              40  United-States  <=50K
# 32559             0             0              20  United-States  <=50K
# 32560         15024             0              40  United-States   >50K
#
# [32561 rows x 19 columns]

# %%
# TEST CASES for Question 1

assert len(linking_attack(['Zip'])) == 43191
assert len(linking_attack(['Zip', 'DOB'])) == 32563
assert len(linking_attack(['Zip', 'Age'])) == 32755

# %% [markdown]
# ## Question 2 (5 points)
#
# How many individuals in this dataset are uniquely identified by their Zip code? How many are uniquely identified by their age?
#
# Hint: note that the number of *unique ZIP codes* is **different** from the number of *individuals uniquely identified by ZIP code*.
#
# Hint: you can use the `value_counts` method to count the number of occurences of each value in a series.

# %%
def unique_zipcode():
    return len(adult_merged['Zip'].value_counts()[adult_merged['Zip'].value_counts() < 2])

def unique_dob():
    return len(adult_merged['DOB'].value_counts()[adult_merged['DOB'].value_counts() < 2])

# %%
zipcode_count = unique_zipcode()
zipcode_count
# Out:
# 23513

# %%
dob_count = unique_dob()
dob_count
# Out:
# 7845

# %%
# TEST CASES (INCOMPLETE) for Question 2
# INCOMPLETE means that additional test cases will be used to check your answer during grading

assert unique_zipcode() > 0
assert unique_dob() > 0

# %% [markdown]
# ## Question 3 (10 points)
#
# Write code to determine the `Education-Num` of the individual named Ardyce Golby by performing a differencing attack. Your code should *only* use aggregate data to find Ardyce's education number.

# %%
def ardyce_education():
    # Differencing attack
    s1 = adult['Education-Num'].sum()
    s2 = adult[adult['Name'] != 'Ardyce Golby']['Education-Num'].sum()
    return s1 - s2

# %%
ardyce_golby = ardyce_education()
ardyce_golby
# Out:
# 12

# %%
# TEST CASE for Question 3
assert ardyce_education() == 12
